# %%
import pandas as pd

# %%
property_pd = pd.read_csv(r'C:\Users\jfoo\OneDrive - tvsdesign\MACAD\03_AIA\01_GRAPHML\cleaned_property_data.csv')
property_pd.head()
# Out:
# c:\Users\jfoo\AppData\Local\miniconda3\envs\graphml\lib\site-packages\IPython\core\interactiveshell.py:3508: DtypeWarning: Columns (1,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Unnamed: 0        BBLE  BORO  BLOCK   LOT EASEMENT        OWNER BLDGCL  \
# 0        3514  1009281654     1    928  1654      NaN          NaN     R4
# 1        3519  1009281661     1    928  1661      NaN          NaN     R4
# 2        3544  1010511417     1   1051  1417      NaN          NaN     R4
# 3        7066  1006371201     1    637  1201      NaN          NaN     R8
# 4       10598  1002791006     1    279  1006      NaN  U CHOI WONG     R1
#
#   TAXCLASS  LTFRONT  ...  VALTYPE    Borough   Latitude  Longitude  \
# 0        2        0  ...    AC-TR  MANHATTAN  40.736451 -73.978732
# 1        2        0  ...    AC-TR  MANHATTAN  40.736451 -73.978732
# 2        2        0  ...    AC-TR  MANHATTAN  40.759212 -73.994510
# 3       2C        0  ...    AC-TR  MANHATTAN  40.735330 -74.009670
# 4       2C        0  ...    AC-TR  MANHATTAN  40.712189 -73.997843
#
#    Community Board  Council District  Census Tract        BIN           NTA  \
# 0            106.0               2.0          64.0  1086124.0      Gramercy
# 1            106.0               2.0          64.0  1086124.0      Gramercy
# 2            104.0               3.0         115.0  1088437.0       Clinton
# 3            102.0               3.0          75.0  1012003.0  West Village
# 4            103.0               1.0          27.0  1003389.0     Chinatown
#
#        New Georeferenced Column
# 0  POINT (-73.978732 40.736451)
# 1  POINT (-73.978732 40.736451)
# 2   POINT (-73.99451 40.759212)
# 3    POINT (-74.00967 40.73533)
# 4  POINT (-73.997843 40.712189)
#
# [5 rows x 41 columns]

# %%
manhattan_df = property_pd[property_pd['BORO'] == 1]
len(manhattan_df)
# Out:
# 1341059

# %%
clean_df = manhattan_df.dropna(subset = ['Latitude'])
len(clean_df)
# Out:
# 1341059

# %%
clean_value_df = clean_df.dropna(subset = ['AVTOT'])
len(clean_value_df)
# Out:
# 1341059

# %%
value_df = clean_value_df[clean_value_df['AVTOT'] != 0]
final_df = value_df.drop(['EASEMENT', 'OWNER'], axis= 'columns')
final_df.to_csv('cleaned_property_data.zip')
final_df.head()
# Out:
#    Unnamed: 0        BBLE  BORO  BLOCK   LOT BLDGCL TAXCLASS  LTFRONT  \
# 0        3514  1009281654     1    928  1654     R4        2        0
# 1        3519  1009281661     1    928  1661     R4        2        0
# 2        3544  1010511417     1   1051  1417     R4        2        0
# 3        7066  1006371201     1    637  1201     R8       2C        0
# 4       10598  1002791006     1    279  1006     R1       2C        0
#
#    LTDEPTH  EXT  ...  VALTYPE    Borough   Latitude  Longitude  \
# 0        0  NaN  ...    AC-TR  MANHATTAN  40.736451 -73.978732
# 1        0  NaN  ...    AC-TR  MANHATTAN  40.736451 -73.978732
# 2        0  NaN  ...    AC-TR  MANHATTAN  40.759212 -73.994510
# 3        0  NaN  ...    AC-TR  MANHATTAN  40.735330 -74.009670
# 4        0  NaN  ...    AC-TR  MANHATTAN  40.712189 -73.997843
#
#    Community Board  Council District  Census Tract        BIN           NTA  \
# 0            106.0               2.0          64.0  1086124.0      Gramercy
# 1            106.0               2.0          64.0  1086124.0      Gramercy
# 2            104.0               3.0         115.0  1088437.0       Clinton
# 3            102.0               3.0          75.0  1012003.0  West Village
# 4            103.0               1.0          27.0  1003389.0     Chinatown
#
#        New Georeferenced Column
# 0  POINT (-73.978732 40.736451)
# 1  POINT (-73.978732 40.736451)
# 2   POINT (-73.99451 40.759212)
# 3    POINT (-74.00967 40.73533)
# 4  POINT (-73.997843 40.712189)
#
# [5 rows x 39 columns]
